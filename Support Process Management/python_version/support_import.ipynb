# %%
import os
import pandas as pd
import numpy as np
import sqlite3

from tqdm import tqdm
from datetime import datetime

tqdm.pandas()

import warnings
warnings.filterwarnings("ignore")

# %%
def create_nested_dataframe(df, filter_col, filter_val, header_col, header_val):
    """
    주어진 데이터프레임에서 특정 필터 조건에 맞는 데이터를 먼저 추출하고,
    다시 해당 조건 중 값을 가진 레코드를 헤더로 사용하는 중첩 데이터프레임을 생성

    Parameters:
    df (pd.DataFrame): 원본 데이터프레임
    filter_col (str): 필터링에 사용할 컬럼명
    filter_val (any): 필터링 조건에 사용할 값
    header_col (str): 헤더로 사용할 레코드를 찾기 위한 컬럼명
    header_val (any): 헤더로 사용할 레코드를 찾기 위한 값

    Returns:
    pd.DataFrame: 헤더를 설정한 새로운 중첩 데이터프레임
    """
    # 필터링 조건에 맞는 데이터프레임 생성
    filtered_df = df[df[filter_col] == filter_val]

    # 헤더로 사용할 레코드 찾기
    header = filtered_df[filtered_df[header_col] == header_val].iloc[0]

    # 나머지 데이터를 새로운 데이터프레임으로 구성
    nested_df = filtered_df[filtered_df[header_col] != header_val].reset_index(drop=True)

    # 새 데이터프레임의 컬럼명을 헤더로 설정
    nested_df.columns = header

    # 'Unnamed'로 시작하는 모든 열을 드롭
    nested_df = nested_df.loc[:, ~nested_df.columns.astype(str).str.startswith('Unnamed')]
    nested_df = nested_df.loc[:, ~nested_df.columns.astype(str).str.contains('nan', case=False)]

    return nested_df

# %%
## step 0 : define the path of the data

db_path = os.path.join(os.getcwd(), '2101_240526.sqlite3')
output_path = os.path.join(os.getcwd(), "2101_테스트용_빈 파일.xlsx")

# %%
## step 1 : connect to the database and read data as dataframe
conn = sqlite3.connect(db_path)
indiv_table_name = "2101_개별속성"
df = pd.read_sql_query(f'SELECT * FROM "{indiv_table_name}"', conn)

# %%
## step 2 : load working file
df_output = pd.read_excel(output_path)

# %%
df_output.head()
# Out:
#           SR No  작업자      출처  \
# 0         SR No  작업자      출처
# 1  DOF522002061   AC  1.0PID
# 2  DOF522004113   AC  1.0PID
# 3  DOF522005601   AC  1.0PID
# 4         SR No  작업자      출처
#
#                                                 파일목록   공정   비고     Tag No  \
# 0                                               파일목록   공정   비고     Tag No
# 1  B7S38-522-S0002,Column Data Sheet.xlsx,D-522-A...  522  NaN  522-C-108
# 2  Column Data Sheet.xlsx,D-522-A205,HCR팀 - 522-L...  522  NaN  522-C-106
# 3  Column Data Sheet.xlsx,D-522-A212,HCR팀 - 522-L...  522  NaN  522-C-109
# 4                                               파일목록   공정   비고     Tag No
#
#    Tag No 수정             카테고리     클래스  ... 속성3242 속성3243  속성3244 속성3245  \
# 0  Tag No 수정  FIXED EQUIPMENT  VESSEL  ...    NaN    NaN     NaN    NaN
# 1  522-C-108  FIXED EQUIPMENT  VESSEL  ...    NaN    NaN     NaN    NaN
# 2  522-C-106  FIXED EQUIPMENT  VESSEL  ...    NaN    NaN     NaN    NaN
# 3  522-C-109  FIXED EQUIPMENT  VESSEL  ...    NaN    NaN     NaN    NaN
# 4  Tag No 수정  FIXED EQUIPMENT  VESSEL  ...    NaN    NaN     NaN    NaN
#
#   속성3246 속성3247 속성3248 속성3249 속성3250 속성3251
# 0    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 3266 columns]

# %%
df.head()
# Out:
#            SRNo 속성순번              속성값   공정                              C|C|T  \
# 0  DOF522002061  속성1   3810mm /2740mm  522      FIXED EQUIPMENT|VESSEL|COLUMN
# 1  DOF522004113  속성1  1680mm / 3048mm  522      FIXED EQUIPMENT|VESSEL|COLUMN
# 2  DOF522005601  속성1          1220|mm  522      FIXED EQUIPMENT|VESSEL|COLUMN
# 3  DOF522000246  속성1          1900|mm  522  FIXED EQUIPMENT|VESSEL|HORIZONTAL
# 4  DOF522000344  속성1          2300|mm  522  FIXED EQUIPMENT|VESSEL|HORIZONTAL
#
#               속성명                   SR_No_ATTR
# 0  HEADER SIZE ID  DOF522002061|HEADER SIZE ID
# 1  HEADER SIZE ID  DOF522004113|HEADER SIZE ID
# 2  HEADER SIZE ID  DOF522005601|HEADER SIZE ID
# 3  HEADER SIZE ID  DOF522000246|HEADER SIZE ID
# 4  HEADER SIZE ID  DOF522000344|HEADER SIZE ID

# %%
df_pivot = df[df['SRNo'] == "DOF522002061"]
df_pivot = df_pivot[['SRNo', '속성순번', '속성값']].pivot(index='SRNo', columns='속성명', values='속성값')
df_pivot = df_pivot.reset_index(drop=False)

# %%
nested_df = create_nested_dataframe(df_output, 'C|C|T', 'FIXED EQUIPMENT|VESSEL|COLUMN', '속성 그룹 코드', '01_속성명')

# %%
df_pivot
# Out:
# 속성명                   DESIGN CONDITION CORROSION ALLOWANCE HEAD  \
# SRNo
# DOF522002061  CORROSION ALLOW. - TOP HEAD&SHELL TO 3M BELOW ...
#
# 속성명                  DESIGN CONDITION CORROSION ALLOWANCE SHELL  \
# SRNo
# DOF522002061  CORROSION ALLOW. - TOP HEAD&SHELL TO 3M BELOW ...
#
# 속성명          DESIGN CONDITION DESIGN PRESSURE CASE 1  \
# SRNo
# DOF522002061                            3.5|kg/cm^2g
#
# 속성명          DESIGN CONDITION DESIGN PRESSURE CASE 2  \
# SRNo
# DOF522002061                                    None
#
# 속성명          DESIGN CONDITION DESIGN TEMPERATURE CASE 1  \
# SRNo
# DOF522002061                                   371|degC
#
# 속성명          DESIGN CONDITION DESIGN TEMPERATURE CASE 2  \
# SRNo
# DOF522002061                                       None
#
# 속성명          DESIGN CONDITION INSULATION THICKNESS  \
# SRNo
# DOF522002061                                 70|mm
#
# 속성명          DESIGN CONDITION INSULATION TYPE  \
# SRNo
# DOF522002061                              HOT
#
# 속성명                   DESIGN CONDITION MAT HEAD  \
# SRNo
# DOF522002061  SA516-70 / SA516-70+410S S.S CLAD
#
# 속성명                  DESIGN CONDITION MAT SHELL  ... REFRACTORY TYPE REMARK  \
# SRNo                                             ...
# DOF522002061  SA516-70 / SA516-70+410S S.S CLAD  ...            None   None
#
# 속성명          SITE CONDITIONS AMB TEMPERATURE MAXIMUM  \
# SRNo
# DOF522002061                               37.1|degC
#
# 속성명          SITE CONDITIONS AMB TEMPERATURE MINIMUM  \
# SRNo
# DOF522002061                              -10.9|degC
#
# 속성명          SITE CONDITIONS EARTHQUAKE FACTOR SITE CONDITIONS WIND VELOCITY  \
# SRNo
# DOF522002061                           ZONE 2A                        45|m/s
#
# 속성명          WEIGHTS AND PAINT REQUIRED WEIGHT EMPTY  \
# SRNo
# DOF522002061                               142940|kg
#
# 속성명          WEIGHTS AND PAINT REQUIRED WEIGHT FULL WATER  \
# SRNo
# DOF522002061                                    473940|kg
#
# 속성명          WEIGHTS AND PAINT REQUIRED WEIGHT OPERATING  \
# SRNo
# DOF522002061                                   194840|kg
#
# 속성명          WEIGHTS AND PAINT REQUIRED WEIGHT TEST
# SRNo
# DOF522002061                                   None
#
# [1 rows x 89 columns]

# %%
nested_df
# Out:
# 0            작업자      출처                                               파일목록  \
# SR No
# DOF522002061  AC  1.0PID  B7S38-522-S0002,Column Data Sheet.xlsx,D-522-A...
# DOF522004113  AC  1.0PID  Column Data Sheet.xlsx,D-522-A205,HCR팀 - 522-L...
# DOF522005601  AC  1.0PID  Column Data Sheet.xlsx,D-522-A212,HCR팀 - 522-L...
#
# 0              공정   비고     Tag No  Tag No 수정  FIXED EQUIPMENT  VESSEL  COLUMN  \
# SR No
# DOF522002061  522  NaN  522-C-108  522-C-108  FIXED EQUIPMENT  VESSEL  COLUMN
# DOF522004113  522  NaN  522-C-106  522-C-106  FIXED EQUIPMENT  VESSEL  COLUMN
# DOF522005601  522  NaN  522-C-109  522-C-109  FIXED EQUIPMENT  VESSEL  COLUMN
#
# 0             ... DESIGN CONDITION MAT HEAD  \
# SR No         ...
# DOF522002061  ...                       NaN
# DOF522004113  ...                       NaN
# DOF522005601  ...                       NaN
#
# 0             DESIGN CONDITION TEST PRESSURE HYDROSTATIC  \
# SR No
# DOF522002061                                         NaN
# DOF522004113                                         NaN
# DOF522005601                                         NaN
#
# 0            DESIGN CONDITION TEST PRESSURE PNEUMATIC  \
# SR No
# DOF522002061                                      NaN
# DOF522004113                                      NaN
# DOF522005601                                      NaN
#
# 0            DESIGN CONDITION RADIO GRAPHY SHELL  \
# SR No
# DOF522002061                                 NaN
# DOF522004113                                 NaN
# DOF522005601                                 NaN
#
# 0            DESIGN CONDITION RADIO GRAPHY HEAD  \
# SR No
# DOF522002061                                NaN
# DOF522004113                                NaN
# DOF522005601                                NaN
#
# 0            DESIGN CONDITION INSULATION TYPE  \
# SR No
# DOF522002061                              NaN
# DOF522004113                              NaN
# DOF522005601                              NaN
#
# 0            DESIGN CONDITION INSULATION THICKNESS  \
# SR No
# DOF522002061                                   NaN
# DOF522004113                                   NaN
# DOF522005601                                   NaN
#
# 0            DESIGN CONDITION STRESS RELIEF MATERIAL SHELL MATERIAL HEAD
# SR No
# DOF522002061                            NaN            NaN           NaN
# DOF522004113                            NaN            NaN           NaN
# DOF522005601                            NaN            NaN           NaN
#
# [3 rows x 69 columns]

# %%
update_columns = df_pivot.columns.to_list()

# %%
nested_df.set_index('SR No', inplace=True)
df_pivot.set_index('SRNo', inplace=True)

# %%
nested_df.update(df_pivot[update_columns])

# %%
nested_df
# Out:
# 0            작업자      출처                                               파일목록  \
# SR No
# DOF522002061  AC  1.0PID  B7S38-522-S0002,Column Data Sheet.xlsx,D-522-A...
# DOF522004113  AC  1.0PID  Column Data Sheet.xlsx,D-522-A205,HCR팀 - 522-L...
# DOF522005601  AC  1.0PID  Column Data Sheet.xlsx,D-522-A212,HCR팀 - 522-L...
#
# 0              공정   비고     Tag No  Tag No 수정  FIXED EQUIPMENT  VESSEL  COLUMN  \
# SR No
# DOF522002061  522  NaN  522-C-108  522-C-108  FIXED EQUIPMENT  VESSEL  COLUMN
# DOF522004113  522  NaN  522-C-106  522-C-106  FIXED EQUIPMENT  VESSEL  COLUMN
# DOF522005601  522  NaN  522-C-109  522-C-109  FIXED EQUIPMENT  VESSEL  COLUMN
#
# 0             ...          DESIGN CONDITION MAT HEAD  \
# SR No         ...
# DOF522002061  ...  SA516-70 / SA516-70+410S S.S CLAD
# DOF522004113  ...                                NaN
# DOF522005601  ...                                NaN
#
# 0             DESIGN CONDITION TEST PRESSURE HYDROSTATIC  \
# SR No
# DOF522002061                               5.03|kg/cm^2g
# DOF522004113                                         NaN
# DOF522005601                                         NaN
#
# 0            DESIGN CONDITION TEST PRESSURE PNEUMATIC  \
# SR No
# DOF522002061                                      NaN
# DOF522004113                                      NaN
# DOF522005601                                      NaN
#
# 0            DESIGN CONDITION RADIO GRAPHY SHELL  \
# SR No
# DOF522002061                           SPOT/FULL
# DOF522004113                                 NaN
# DOF522005601                                 NaN
#
# 0            DESIGN CONDITION RADIO GRAPHY HEAD  \
# SR No
# DOF522002061                               FULL
# DOF522004113                                NaN
# DOF522005601                                NaN
#
# 0            DESIGN CONDITION INSULATION TYPE  \
# SR No
# DOF522002061                              HOT
# DOF522004113                              NaN
# DOF522005601                              NaN
#
# 0            DESIGN CONDITION INSULATION THICKNESS  \
# SR No
# DOF522002061                                 70|mm
# DOF522004113                                   NaN
# DOF522005601                                   NaN
#
# 0            DESIGN CONDITION STRESS RELIEF  \
# SR No
# DOF522002061                            NaN
# DOF522004113                            NaN
# DOF522005601                            NaN
#
# 0                                MATERIAL SHELL  \
# SR No
# DOF522002061  SA516-70 / SA516-70+410S S.S CLAD
# DOF522004113                                NaN
# DOF522005601                                NaN
#
# 0                                 MATERIAL HEAD
# SR No
# DOF522002061  SA516-70 / SA516-70+410S S.S CLAD
# DOF522004113                                NaN
# DOF522005601                                NaN
#
# [3 rows x 69 columns]
